# %% [markdown]
# # Create Xcalibur sequence

# %%
# INPUT
path = 'sequence_builder_sheet.xlsx'

import pandas as pd

# import excel spreadsheet, segment into bits
data = pd.read_excel(path, skiprows=1)
durs = data.iloc[0:3,1:4]
locs = data.iloc[5:,1:5].reset_index(drop=True).dropna()
locs.columns=data.iloc[4,1:5]
seq = data.iloc[:,6:8].dropna()
other_data = data.iloc[:,10]
other_data.index = data.iloc[:,9]

# import parameters
total_injection_vol = other_data.loc['injection_volume']+other_data.loc['dead_volume']
vial_bottom_vol = other_data.loc['vial_bottom_vol']
injection_dur_min = other_data.loc['injection_duration']

# identify internal standard
locs_IS = locs[locs['Type']=='Internal standard'].reset_index(drop=True)

if len(locs_IS['Name'].unique())==1:
    IS_name = locs_IS.loc[:,'Name'].iloc[0]
    IS_injections = pd.Series(name='Location')
    m=0
    for i in locs_IS.index:
        n_inj = int((locs_IS.loc[i,'Volume']-vial_bottom_vol)/total_injection_vol)
        for _ in range(n_inj):
            IS_injections[m] = locs_IS.loc[i,'Location']
            m=m+1
    print('Found internal standard',IS_name, 'at positions\n',locs_IS['Location'],'\nTotal volume',locs_IS['Volume'].sum(),'ul (',len(IS_injections),'injections)\n')
else:
    print("Couldn't identify internal standard\n")

# Build sequence
sequence = pd.DataFrame(columns = ['Sample Type','File Name','Sample ID','Path','Instrument Method','Position','Inj Vol','Sample Name'])
print('Building sequence')
# tracers
m_IS = 0
n = 0

warmupdur = durs.loc[durs['Block type'].str.startswith('Warmup'),'n_injections'].iloc[0]
warmupmeth = durs.loc[durs['Block type'].str.startswith('Warmup'),'inst_method'].iloc[0]
n_blocks = durs.loc[durs['Block type'].str.startswith('Sample'),'n_injections'].iloc[0]
blockmeth = durs.loc[durs['Block type'].str.startswith('Sample'),'inst_method'].iloc[0]
n_blanks = durs.loc[durs['Block type'].str.startswith('Blank'),'n_injections'].iloc[0]
blankmeth = durs.loc[durs['Block type'].str.startswith('Blank'),'inst_method'].iloc[0]

# add warmup blocks
for _ in range(warmupdur):
    # add IS
    sequence.loc[n,['Sample Type','Sample Name','Position','Instrument Method']] = ['Internal standard',IS_name,IS_injections[m_IS],warmupmeth]
    m_IS+=1
    n+=1
    locs.loc[locs['Location']==IS_injections[m_IS],['Volume']]-=total_injection_vol
    if locs.loc[locs['Location']==IS_injections[m_IS]].loc[:,'Volume'].iloc[0]<vial_bottom_vol:
        print('Warning: vial empty for',IS_injections[m_IS])
        
# build injection list
samples_list=[]
for i in seq.index:
    name=[seq.loc[i,'Name']]
    num=int(seq.loc[i,'Num'])
    samples_list+=num*name
# randomize order of list
import random
random.shuffle(samples_list)

# work through randomized list
for name in samples_list:
    # find vial location
    if len(locs[locs['Name']==name])==1:
        row = locs.loc[locs['Name']==name]
        
        if sequence['Sample Name'].iloc[-1] != IS_name:
            # add IS
            sequence.loc[n,['Sample Type','Sample Name','Position','Instrument Method']] = ['Internal standard', IS_name , IS_injections[m_IS], blockmeth ]
            n+=1
            m_IS+=1
            locs.loc[locs['Location']==IS_injections[m_IS],['Volume']]-=total_injection_vol
            if locs.loc[locs['Location']==IS_injections[m_IS]].loc[:,'Volume'].iloc[0]<vial_bottom_vol:
                print('Warning: vial empty for',IS_injections[m_IS])
           
        # add sample
        sequence.loc[n,['Sample Type','Sample Name','Position','Instrument Method']] = [row['Type'].iloc[0], row['Name'].iloc[0] , row['Location'].iloc[0], blockmeth ]
        n+=1
        locs.loc[locs['Name']==name,['Volume']]-=total_injection_vol
        if locs.loc[locs['Name']==name].loc[:,'Volume'].iloc[0]<vial_bottom_vol:
            print('Warning: vial empty for',IS_injections[m_IS])
        # add IS
        sequence.loc[n,['Sample Type','Sample Name','Position','Instrument Method']] = ['Internal standard', IS_name , IS_injections[m_IS], blockmeth ]
        n+=1
        m_IS+=1
        locs.loc[locs['Location']==IS_injections[m_IS],['Volume']]-=total_injection_vol
        if locs.loc[locs['Location']==IS_injections[m_IS]].loc[:,'Volume'].iloc[0]<vial_bottom_vol:
            print('Warning: vial empty for',IS_injections[m_IS])
                    
# add other colummns
path_col = other_data.loc['path']
filename = [other_data['name_prefix']+f"{id+1:003}" for id in sequence.index]
s_id = sequence.index+1
inj_vol = other_data.loc['injection_volume']

sequence.loc[:,'Path'] = path_col
sequence.loc[:,'File Name'] = filename
sequence.loc[:,'Sample ID'] = s_id
sequence.loc[:,'Inj Vol'] = inj_vol


sequence_dur_hrs = (n-1)*injection_dur_min/60

print('\nSequence duration:',sequence_dur_hrs,'hours')

print('\nRemaining volumes:\n',locs)

# save sequence as csv
sequence.to_csv('sequence.csv',index=False)

# add Bracket Type = 4 to start of file
file_path = 'sequence.csv'
with open(file_path, 'r') as file:
    content = file.readlines()
content.insert(0, 'Bracket Type=4,,,,,,,\n')
with open(file_path, 'w') as file:
    file.writelines(content)
# Out:
# Found internal standard VS-IS at positions
#  0    B:F9
# 1    B:F2
# 2    B:F3
# 3    B:F4
# 4    B:F5
# 5    B:F6
# 6    B:F7
# 7    B:F8
# 8    B:F9
# Name: Location, dtype: object
# Total volume 9000 ul ( 288 injections)
#
# Building sequence
#
# Sequence duration: 46.2 hours
#
# Remaining volumes:
#  4                Type      Name Location Volume
# 0   Internal standard     VS-IS     B:F9     70
# 1   Internal standard     VS-IS     B:F2     40
# 2   Internal standard     VS-IS     B:F3     40
# 3   Internal standard     VS-IS     B:F4    250
# 4   Internal standard     VS-IS     B:F5   1000
# 5   Internal standard     VS-IS     B:F6   1000
# 6   Internal standard     VS-IS     B:F7   1000
# 7   Internal standard     VS-IS     B:F8   1000
# 8   Internal standard     VS-IS     B:F9     70
# 9               Blank      MeOH     B:C1    470
# 10              Blank      MQ-0     B:C2    470
# 11              Blank      MQ-1     B:C3    470
# 12              Blank      MQ-2     B:C4    470
# 13           Standard      S1-1     B:D1    320
# 14           Standard      S2-1     B:D2    320
# 15           Standard      VS-1     B:D3    320
# 16           Standard      S1-2     B:D4    320
# 17           Standard      S2-2     B:D5    320
# 18           Standard      VS-2     B:D6    320
# 19             Sample      DC-1     B:D7    320
# 20             Sample      DC-3     B:D8    320
# 21             Sample      DC-6     B:D9    320
# 22             Sample      DC-9     B:E1    320
# 23             Sample     DC-12     B:E2    320
# 24             Sample     DC-16     B:E3    320
# 25             Sample  DC-18-20     B:E4    320
# 26             Sample  DC-21-24     B:E5    320
# 27             Sample  DC-27-28     B:E6    320
# 28             Sample     DC-30     B:E7    320
# 29             Sample     DC-34     B:E8    320
# 30             Sample     DC-38     B:E9    320

# %%
sequence.head(50)
# Out:
#           Sample Type   File Name Sample ID  \
# 0   Internal standard  250123_001         1
# 1   Internal standard  250123_002         2
# 2   Internal standard  250123_003         3
# 3   Internal standard  250123_004         4
# 4   Internal standard  250123_005         5
# 5   Internal standard  250123_006         6
# 6   Internal standard  250123_007         7
# 7   Internal standard  250123_008         8
# 8            Standard  250123_009         9
# 9   Internal standard  250123_010        10
# 10             Sample  250123_011        11
# 11  Internal standard  250123_012        12
# 12             Sample  250123_013        13
# 13  Internal standard  250123_014        14
# 14           Standard  250123_015        15
# 15  Internal standard  250123_016        16
# 16           Standard  250123_017        17
# 17  Internal standard  250123_018        18
# 18             Sample  250123_019        19
# 19  Internal standard  250123_020        20
# 20             Sample  250123_021        21
# 21  Internal standard  250123_022        22
# 22           Standard  250123_023        23
# 23  Internal standard  250123_024        24
# 24           Standard  250123_025        25
# 25  Internal standard  250123_026        26
# 26             Sample  250123_027        27
# 27  Internal standard  250123_028        28
# 28             Sample  250123_029        29
# 29  Internal standard  250123_030        30
# 30             Sample  250123_031        31
# 31  Internal standard  250123_032        32
# 32             Sample  250123_033        33
# 33  Internal standard  250123_034        34
# 34             Sample  250123_035        35
# 35  Internal standard  250123_036        36
# 36             Sample  250123_037        37
# 37  Internal standard  250123_038        38
# 38           Standard  250123_039        39
# 39  Internal standard  250123_040        40
# 40             Sample  250123_041        41
# 41  Internal standard  250123_042        42
# 42             Sample  250123_043        43
# 43  Internal standard  250123_044        44
# 44           Standard  250123_045        45
# 45  Internal standard  250123_046        46
# 46           Standard  250123_047        47
# 47  Internal standard  250123_048        48
# 48             Sample  250123_049        49
# 49  Internal standard  250123_050        50
#
#                                                  Path  \
# 0   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 1   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 2   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 3   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 4   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 5   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 6   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 7   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 8   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 9   C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 10  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 11  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 12  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 13  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 14  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 15  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 16  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 17  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 18  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 19  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 20  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 21  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 22  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 23  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 24  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 25  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 26  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 27  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 28  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 29  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 30  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 31  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 32  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 33  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 34  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 35  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 36  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 37  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 38  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 39  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 40  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 41  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 42  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 43  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 44  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 45  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 46  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 47  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 48  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
# 49  C:\Xcalibur\data\DC aerosol\250123_DC-2011-2_M...
#
#                                     Instrument Method Position Inj Vol  \
# 0   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 1   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 2   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 3   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 4   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 5   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 6   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 7   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 8   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D2      25
# 9   C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 10  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E6      25
# 11  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 12  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E5      25
# 13  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 14  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D5      25
# 15  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 16  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D5      25
# 17  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 18  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E8      25
# 19  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 20  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E7      25
# 21  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 22  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D5      25
# 23  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 24  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D1      25
# 25  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 26  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D9      25
# 27  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 28  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E5      25
# 29  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 30  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E4      25
# 31  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 32  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E4      25
# 33  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 34  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E3      25
# 35  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 36  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E1      25
# 37  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 38  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D3      25
# 39  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 40  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D7      25
# 41  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 42  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D9      25
# 43  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 44  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D2      25
# 45  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 46  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:D1      25
# 47  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
# 48  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:E4      25
# 49  C:\Xcalibur\methods\Vanquish_Neo\IFI_A50-50B\S...     R:F1      25
#
#    Sample Name
# 0        VS-IS
# 1        VS-IS
# 2        VS-IS
# 3        VS-IS
# 4        VS-IS
# 5        VS-IS
# 6        VS-IS
# 7        VS-IS
# 8         S2-1
# 9        VS-IS
# 10    DC-27-28
# 11       VS-IS
# 12    DC-21-24
# 13       VS-IS
# 14        S2-2
# 15       VS-IS
# 16        S2-2
# 17       VS-IS
# 18       DC-34
# 19       VS-IS
# 20       DC-30
# 21       VS-IS
# 22        S2-2
# 23       VS-IS
# 24        S1-1
# 25       VS-IS
# 26        DC-6
# 27       VS-IS
# 28    DC-21-24
# 29       VS-IS
# 30    DC-18-20
# 31       VS-IS
# 32    DC-18-20
# 33       VS-IS
# 34       DC-16
# 35       VS-IS
# 36        DC-9
# 37       VS-IS
# 38        VS-1
# 39       VS-IS
# 40        DC-1
# 41       VS-IS
# 42        DC-6
# 43       VS-IS
# 44        S2-1
# 45       VS-IS
# 46        S1-1
# 47       VS-IS
# 48    DC-18-20
# 49       VS-IS
